# %% [markdown]
# # Convolutional Neural Networks
#
# you'll be coding up a convolutional neural network from scratch to classify images using PyTorch.
#
# ### Instructions
# - The maximum number of parameters you are allowed to use for your network is **100,000**.
# - You are required to complete the functions defined in the code blocks following each question. Fill out sections of the code marked `"YOUR CODE HERE"`.
# - You're free to add any number of methods within each class.
# - You may also add any number of additional code blocks that you deem necessary.

# %% [markdown]
# ## Install Dependencies

# %%
# !pip3 install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)

# %%
# !pip install torchinfo
# Out:
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.7/dist-packages (1.6.5)

# %%
# 
# Checking if hardware acceleration enabled
import os 
if int(os.environ['COLAB_GPU']) > 0:
  print ("*** GPU connected")
else:
  print ("*** No hardware acceleration: change to GPU under Runtime > Change runtime type > Hardware accelerator")
# Out:
# *** GPU connected

# %% [markdown]
# ## Data Preparation

# %%
# Importing the libraries
import os
import torch
import torchvision
from torchvision.utils import make_grid
from PIL import Image
import requests
from torch.autograd import Variable

import numpy as np

# %% [markdown]
# In this assignment, we will use the Fashion-MNIST dataset. Fashion-MNIST is a dataset of Zalando's article images—consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes.
#
# ### Data
#
# Each image is 28 pixels in height and 28 pixels in width, for a total of 784 pixels in total. Each pixel has a single pixel-value associated with it, indicating the lightness or darkness of that pixel, with higher numbers meaning darker. This pixel-value is an integer between 0 and 255.
#
# ### Labels
#
# Each training and test example is assigned to one of the following labels:
#
# | Label | Description |
# |-------|-------------|
# | 0     | T-shirt/top |
# | 1     | Trouser     |
# | 2     | Pullover    |
# | 3     | Dress       |
# | 4     | Coat        |
# | 5     | Sandal      |
# | 6     | Shirt       |
# | 7     | Sneaker     |
# | 8     | Bag         |
# | 9     | Ankle boot  |
#
# Fashion-MNIST is included in the `torchvision` library.

# %%
from torchvision.datasets import FashionMNIST
from torchvision.transforms import Compose, ToTensor, Normalize

# %%
# Transform to normalize the data and convert to a tensor
transform = Compose([ToTensor(),
    Normalize((0.5,), (0.5,))
    ])

# Download the data
dataset = FashionMNIST('MNIST_data/', download = True, train = True, transform = transform)

# %% [markdown]
# **NOTE:** You may add more operations to `Compose` if you're performing data augmentation.

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# Let's take a look at the classes in our dataset.

# %%
print(dataset.classes)
# Out:
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
import matplotlib.pyplot as plt

def show_example(img, label):
    print('Label: {} ({})'.format(dataset.classes[label], label))
    plt.imshow(img.squeeze(), cmap='Greys_r')
    plt.axis(False)

# %%
show_example(*dataset[20])
# Out:
# Label: Dress (3)

# %%
show_example(*dataset[20000])
# Out:
# Label: Sneaker (7)

# %% [markdown]
# ## Question 1
#
# ## Creating Training and Validation Datasets

# %% [markdown]
# The `split_indices` function takes in the size of the entire dataset, `n`, the fraction of data to be used as validation set, `val_frac`, and the random seed and returns the indices of the data points to be added to the validation dataset.
#
# **Choose a suitable fraction for your validation set and experiment with the seed. Remember that the better your validation set, the higher the chances that your model would do well on the test set.**

# %%
def split_indices(n, val_frac, seed):
    # Determine the size of the validation set
    n_val = int(val_frac * n)
    np.random.seed(seed)
    # Create random permutation between 0 to n-1
    idxs = np.random.permutation(n)
    # Pick first n_val indices for validation set
    return idxs[n_val:], idxs[:n_val]

# %%
######################
#   YOUR CODE HERE   #
######################
val_frac = 0.3 ## Set the fraction for the validation set
rand_seed = 1  ## Set the random seed

train_indices, val_indices = split_indices(len(dataset), val_frac, rand_seed)
print("#samples in training set: {}".format(len(train_indices)))
print("#samples in validation set: {}".format(len(val_indices)))
# Out:
# #samples in training set: 42000
# #samples in validation set: 18000

# %% [markdown]
# Next, we make use of the built-in dataloaders in PyTorch to create iterables of our our training and validation sets. This helps in avoiding fitting the whole dataset into memory and only loads a batch of the data that we can decide.
#
# **Set the `batch_size` depending on the hardware resource (GPU/CPU RAM) you are using for the assignment.**

# %%
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data.dataloader import DataLoader

# %%
######################
#   YOUR CODE HERE   #
######################
batch_size = 30 ## Set the batch size

# %%
# Training sampler and data loader
train_sampler = SubsetRandomSampler(train_indices)
train_dl = DataLoader(dataset,
                     batch_size,
                     sampler=train_sampler)

# Validation sampler and data loader
val_sampler = SubsetRandomSampler(val_indices)
val_dl = DataLoader(dataset,
                   batch_size,
                   sampler=val_sampler)

# %% [markdown]
# Plot images in a sample batch of data.

# %%
def show_batch(dl):
    for images, labels in dl:
        fig, ax = plt.subplots(figsize=(10,10))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(images, 8).permute(1, 2, 0), cmap='Greys_r')
        break

# %%
show_batch(train_dl)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Question 2
#
# ## Building the Model

# %% [markdown]
# **Create your model by defining the network architecture in the `ImageClassifierNet` class.**
# **NOTE:** The number of parameters in your network must be $\leq$ 100,000.

# %%
# Import the libraries
import torch.nn as nn
import torch.nn.functional as F

from torchinfo import summary

# %%
class ImageClassifierNet(nn.Module):
    def __init__(self, n_channels=3):
        super(ImageClassifierNet, self).__init__()
        ######################
        #   YOUR CODE HERE   #
        self.layer1 = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=16, kernel_size=3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        
        self.layer2 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
        self.fc1 = nn.Linear(in_features=32*6*6, out_features=80)
        self.drop = nn.Dropout(0.5)
        self.fc2 = nn.Linear(in_features=80, out_features=31)
        self.fc3 = nn.Linear(in_features=31, out_features=10)
        ######################
        
    def forward(self, X):
        ######################
        #   YOUR CODE HERE   #
        out = self.layer1(X)
        out = self.layer2(out)
        out = out.view(out.size(0), -1)
        out = self.fc1(out)
        out = self.drop(out)
        out = self.fc2(out)
        out = self.fc3(out)
        
        return out
        ######################

# %%
model = ImageClassifierNet()

# %% [markdown]
# The following code block prints your network architecture. It also shows the total number of parameters in your network (see `Total params`).
#
# **NOTE: The total number of parameters in your model should be <= 100,000.**

# %%
summary(model, input_size=(batch_size, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ImageClassifierNet                       --                        --
# ├─Sequential: 1-1                        [30, 16, 14, 14]          --
# │    └─Conv2d: 2-1                       [30, 16, 28, 28]          160
# │    └─BatchNorm2d: 2-2                  [30, 16, 28, 28]          32
# │    └─ReLU: 2-3                         [30, 16, 28, 28]          --
# │    └─MaxPool2d: 2-4                    [30, 16, 14, 14]          --
# ├─Sequential: 1-2                        [30, 32, 6, 6]            --
# │    └─Conv2d: 2-5                       [30, 32, 12, 12]          4,640
# │    └─BatchNorm2d: 2-6                  [30, 32, 12, 12]          64
# │    └─ReLU: 2-7                         [30, 32, 12, 12]          --
# │    └─MaxPool2d: 2-8                    [30, 32, 6, 6]            --
# ├─Linear: 1-3                            [30, 80]                  92,240
# ├─Dropout: 1-4                           [30, 80]                  --
# ├─Linear: 1-5                            [30, 31]                  2,511
# ├─Linear: 1-6                            [30, 10]                  320
# ==========================================================================================
# Total params: 99,967
# Trainable params: 99,967
# Non-trainable params: 0
# Total mult-adds (M): 26.66
# ==========================================================================================
# Input size (MB): 0.09
# Forward/backward pass size (MB): 8.26
# Params size (MB): 0.40
# Estimated Total Size (MB): 8.76
# ==========================================================================================

# %% [markdown]
# ## Enable training on a GPU

# %%
def get_default_device():
    """Use GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
    
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl:
            yield to_device(b, self.device)
    
    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()

train_dl = DeviceDataLoader(train_dl, device)
val_dl = DeviceDataLoader(val_dl, device)

to_device(model, device)
# Out:
# ImageClassifierNet(
#   (layer1): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc1): Linear(in_features=1152, out_features=80, bias=True)
#   (drop): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=80, out_features=31, bias=True)
#   (fc3): Linear(in_features=31, out_features=10, bias=True)
# )

# %% [markdown]
# ## Question 3
#
# ## Train the model

# %% [markdown]
# **Complete the `train_model` function to train your model on a dataset. Tune your network architecture and hyperparameters on the validation set.**

# %%
def train_model(n_epochs, model, train_dl, val_dl, loss_fn, opt_fn, lr):
    """
    Trains the model on a dataset.
    
    Args:
        n_epochs: number of epochs
        model: ImageClassifierNet object
        train_dl: training dataloader
        val_dl: validation dataloader
        loss_fn: the loss function
        opt_fn: the optimizer
        lr: learning rate
    
    Returns:
        The trained model. 
        A tuple of (model, train_losses, val_losses, train_accuracies, val_accuracies)
    """
    # Record these values the end of each epoch
    train_losses, val_losses, train_accuracies, val_accuracies = [], [], [], []
    
    total_images = 0
    correct_images = 0
    
    ######################
    #   YOUR CODE HERE   #
    for epoch in range(n_epochs):
        for images, labels in train_dl:
        # Transfering images and labels to GPU if available
            images, labels = images.to(device), labels.to(device)

            #print(images.shape)
            train = Variable(images.view(30,1,28,28))
            labels = Variable(labels)
            #rint(train.shape)

            # Forward pass 
            outputs = model(train)
            #print(outputs)
            loss = loss_fn(outputs, labels)

            # Initializing a gradient as 0 so there is no mixing of gradient among the batches
            opt_fn.zero_grad()

            #Propagating the error backward
            loss.backward()

            # Optimizing the parameters
            opt_fn.step()

            total_images += 30
            predictions = torch.max(outputs, 1)[1].to(device)
            correct_images += (predictions == labels).sum()
        
        #loss = loss.detach().cpu().numpy()
        train_losses.append(loss)
        accuracy = correct_images * 100 / total_images
        accuracy = accuracy.detach().cpu().numpy()
        train_accuracies.append(accuracy)
        print("Train Loss: {}, Train Accuracy: {}%  after epoch {}".format(loss, accuracy, epoch))
        #predictions = 0
        #""""
        correct = 0
        total = 0
        if not val_dl:
            continue
        else:
            for images, labels in val_dl:
                images, labels = images.to(device), labels.to(device)
                #labels_list.append(labels)
                #print(images.shape)

                test = Variable(images.view(30, 1, 28, 28))


                outputs = model(test)
                val_loss = loss_fn(outputs, labels)
                predictions = torch.max(outputs, 1)[1].to(device)
                #predictions_list.append(predictions)
                correct += (predictions == labels).sum()
                total += 30

            #val_loss = val_loss.detach().cpu().numpy()
            val_losses.append(val_loss)
            test_accuracy = correct * 100 / total
            test_accuracy = test_accuracy.detach().cpu().numpy()
            val_accuracies.append(test_accuracy)
            print("Test Loss: {}, Test Accuracy: {}%  after epoch {}".format(val_loss, test_accuracy, epoch))

   

        
        
        
            
       # """
            
    
    # Testing the model
    

    ######################
    
    return model, train_losses, val_losses, train_accuracies , val_accuracies
    #return model, train_losses, train_accuracies

# %% [markdown]
# **Set the maximum number of training epochs, the loss function, the optimizer, and the learning rate.**

# %%
######################
#   YOUR CODE HERE   #
######################


num_epochs = 30 # Max number of training epochs
loss_fn = nn.CrossEntropyLoss() # Define the loss function
lr = 0.001  # Set the learning rate
opt_fn = torch.optim.Adam(model.parameters(), lr=lr) # Select an optimizer

# %%
history = train_model(num_epochs, model, train_dl, val_dl, loss_fn, opt_fn, lr)

# (Optional)
# Once training is finished, save model as .pth and avoid retraining for the following blocks
# Out:
# Train Loss: 0.20594382286071777, Train Accuracy: 82.5%  after epoch 0
# Test Loss: 0.42671361565589905, Test Accuracy: 86.6611099243164%  after epoch 0
# Train Loss: 0.3548727035522461, Train Accuracy: 85.07737731933594%  after epoch 1
# Test Loss: 0.2192474901676178, Test Accuracy: 88.57221984863281%  after epoch 1
# Train Loss: 0.4265541136264801, Train Accuracy: 86.42936706542969%  after epoch 2
# Test Loss: 0.42227908968925476, Test Accuracy: 88.56666564941406%  after epoch 2
# Train Loss: 0.23951345682144165, Train Accuracy: 87.30535888671875%  after epoch 3
# Test Loss: 0.46151313185691833, Test Accuracy: 88.95000457763672%  after epoch 3
# Train Loss: 0.5873565077781677, Train Accuracy: 87.970947265625%  after epoch 4
# Test Loss: 0.18244671821594238, Test Accuracy: 89.72777557373047%  after epoch 4
# Train Loss: 0.430608332157135, Train Accuracy: 88.50794219970703%  after epoch 5
# Test Loss: 0.3277861475944519, Test Accuracy: 90.17778015136719%  after epoch 5
# Train Loss: 0.2793630361557007, Train Accuracy: 88.92720794677734%  after epoch 6
# Test Loss: 0.21613839268684387, Test Accuracy: 89.97222137451172%  after epoch 6
# Train Loss: 0.19555515050888062, Train Accuracy: 89.28541564941406%  after epoch 7
# Test Loss: 0.3777652382850647, Test Accuracy: 90.26667022705078%  after epoch 7
# Train Loss: 0.10895860940217972, Train Accuracy: 89.60556030273438%  after epoch 8
# Test Loss: 0.5433251857757568, Test Accuracy: 89.79444885253906%  after epoch 8
# Train Loss: 0.17269007861614227, Train Accuracy: 89.87666320800781%  after epoch 9
# Test Loss: 0.12510432302951813, Test Accuracy: 90.53888702392578%  after epoch 9
# Train Loss: 0.04602339118719101, Train Accuracy: 90.1305160522461%  after epoch 10
# Test Loss: 0.04323525354266167, Test Accuracy: 89.92778015136719%  after epoch 10
# Train Loss: 0.19444765150547028, Train Accuracy: 90.35813903808594%  after epoch 11
# Test Loss: 0.11444378644227982, Test Accuracy: 90.50555419921875%  after epoch 11
# Train Loss: 0.17512144148349762, Train Accuracy: 90.56446838378906%  after epoch 12
# Test Loss: 0.46312808990478516, Test Accuracy: 89.0%  after epoch 12
# Train Loss: 0.1576051115989685, Train Accuracy: 90.76360321044922%  after epoch 13
# Test Loss: 0.12319629639387131, Test Accuracy: 90.72777557373047%  after epoch 13
# Train Loss: 0.1956346482038498, Train Accuracy: 90.94063568115234%  after epoch 14
# Test Loss: 0.34350961446762085, Test Accuracy: 90.0111083984375%  after epoch 14
# Train Loss: 0.15422460436820984, Train Accuracy: 91.10729217529297%  after epoch 15
# Test Loss: 0.13556556403636932, Test Accuracy: 89.92222595214844%  after epoch 15
# Train Loss: 0.3139578104019165, Train Accuracy: 91.26302337646484%  after epoch 16
# Test Loss: 0.14240604639053345, Test Accuracy: 90.3499984741211%  after epoch 16
# Train Loss: 0.14556169509887695, Train Accuracy: 91.4179916381836%  after epoch 17
# Test Loss: 0.19550618529319763, Test Accuracy: 90.00555419921875%  after epoch 17
# Train Loss: 0.43649786710739136, Train Accuracy: 91.55500793457031%  after epoch 18
# Test Loss: 0.45307981967926025, Test Accuracy: 90.5%  after epoch 18
# Train Loss: 0.15347762405872345, Train Accuracy: 91.68798065185547%  after epoch 19
# Test Loss: 0.15978215634822845, Test Accuracy: 90.33333587646484%  after epoch 19
# Train Loss: 0.08479468524456024, Train Accuracy: 91.81451416015625%  after epoch 20
# Test Loss: 0.2902953028678894, Test Accuracy: 90.36111450195312%  after epoch 20
# Train Loss: 0.18608076870441437, Train Accuracy: 91.925537109375%  after epoch 21
# Test Loss: 0.23743633925914764, Test Accuracy: 90.55000305175781%  after epoch 21
# Train Loss: 0.044705506414175034, Train Accuracy: 92.03694915771484%  after epoch 22
# Test Loss: 0.4161983132362366, Test Accuracy: 90.02777862548828%  after epoch 22
# Train Loss: 0.07240547984838486, Train Accuracy: 92.14453887939453%  after epoch 23
# Test Loss: 0.20207446813583374, Test Accuracy: 90.42222595214844%  after epoch 23
# Train Loss: 0.07586383819580078, Train Accuracy: 92.25066375732422%  after epoch 24
# Test Loss: 0.3855662941932678, Test Accuracy: 90.5%  after epoch 24
# Train Loss: 0.20188464224338531, Train Accuracy: 92.34569549560547%  after epoch 25
# Test Loss: 0.18665441870689392, Test Accuracy: 89.9888916015625%  after epoch 25
# Train Loss: 0.24431143701076508, Train Accuracy: 92.43571472167969%  after epoch 26
# Test Loss: 0.7034758925437927, Test Accuracy: 90.42778015136719%  after epoch 26
# Train Loss: 0.05175740271806717, Train Accuracy: 92.52508544921875%  after epoch 27
# Test Loss: 0.2243344783782959, Test Accuracy: 90.39444732666016%  after epoch 27
# Train Loss: 0.15288829803466797, Train Accuracy: 92.61460876464844%  after epoch 28
# Test Loss: 0.6640028357505798, Test Accuracy: 90.29444885253906%  after epoch 28
# Train Loss: 0.16151723265647888, Train Accuracy: 92.69770050048828%  after epoch 29
# Test Loss: 0.23867708444595337, Test Accuracy: 90.22222137451172%  after epoch 29

# %%
model, train_losses, val_losses, train_accuracies, val_accuracies = history

# %% [markdown]
# ## Plot loss and accuracy

# %%
def plot_accuracy(train_accuracies, val_accuracies):
    """Plot accuracies"""
    plt.plot(train_accuracies, "-x")
    plt.plot(val_accuracies, "-o")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend(["Training", "Validation"])
    plt.title("Accuracy vs. No. of epochs")

# %%
plot_accuracy(train_accuracies, val_accuracies)

# %%
for i in range(len(train_losses)):
    train_losses[i] = train_losses[i].detach().cpu().numpy()
    val_losses[i] = val_losses[i].detach().cpu().numpy()

# %%
def plot_losses(train_losses, val_losses):
    """Plot losses"""
    plt.plot(train_losses, "-x")
    plt.plot(val_losses, "-o")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend(["Training", "Validation"])
    plt.title("Loss vs. No. of Epochs")

# %%
plot_losses(train_losses, val_losses)

# %% [markdown]
# ## Train a model on the entire dataset

# %%
indices, _ = split_indices(len(dataset), 0, 1234)
device = get_default_device()

sampler = SubsetRandomSampler(indices)
dl = DataLoader(dataset, batch_size, sampler=sampler)
dl = DeviceDataLoader(dl, device)

# %%
to_device(model, device)
# Out:
# ImageClassifierNet(
#   (layer1): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc1): Linear(in_features=1152, out_features=80, bias=True)
#   (drop): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=80, out_features=31, bias=True)
#   (fc3): Linear(in_features=31, out_features=10, bias=True)
# )

# %% [markdown]
# **Set the maximum number of training epochs and the learning rate for finetuning your model.**

# %%
######################
#   YOUR CODE HERE   #
######################
num_epochs = 20 # Max number of training epochs
lr = 0.001 # Set the learning rate

# %%
history = train_model(num_epochs, model, dl, [], loss_fn, opt_fn, lr)
model = history[0]
# Out:
# Train Loss: 0.06552699953317642, Train Accuracy: 93.59333801269531%  after epoch 0
# Train Loss: 0.2604816257953644, Train Accuracy: 93.711669921875%  after epoch 1
# Train Loss: 0.26256078481674194, Train Accuracy: 93.76777648925781%  after epoch 2
# Train Loss: 0.3361894190311432, Train Accuracy: 93.80875396728516%  after epoch 3
# Train Loss: 0.25152695178985596, Train Accuracy: 93.87200164794922%  after epoch 4
# Train Loss: 0.10838202387094498, Train Accuracy: 93.92361450195312%  after epoch 5
# Train Loss: 0.22391313314437866, Train Accuracy: 93.96690368652344%  after epoch 6
# Train Loss: 0.09309996664524078, Train Accuracy: 94.01041412353516%  after epoch 7
# Train Loss: 0.19787713885307312, Train Accuracy: 94.05592346191406%  after epoch 8
# Train Loss: 0.05758402496576309, Train Accuracy: 94.09683227539062%  after epoch 9
# Train Loss: 0.11230985820293427, Train Accuracy: 94.15258026123047%  after epoch 10
# Train Loss: 0.02786567434668541, Train Accuracy: 94.19597625732422%  after epoch 11
# Train Loss: 0.08973428606987, Train Accuracy: 94.24371337890625%  after epoch 12
# Train Loss: 0.31538671255111694, Train Accuracy: 94.28797912597656%  after epoch 13
# Train Loss: 0.08232560753822327, Train Accuracy: 94.3265609741211%  after epoch 14
# Train Loss: 0.24648885428905487, Train Accuracy: 94.35781860351562%  after epoch 15
# Train Loss: 0.1022513285279274, Train Accuracy: 94.38667297363281%  after epoch 16
# Train Loss: 0.08950738608837128, Train Accuracy: 94.4151840209961%  after epoch 17
# Train Loss: 0.033721305429935455, Train Accuracy: 94.4476318359375%  after epoch 18
# Train Loss: 0.20152521133422852, Train Accuracy: 94.48016357421875%  after epoch 19

# %% [markdown]
# ## Check Predictions

# %%
def view_prediction(img, label, probs, classes):
    """
    Visualize predictions.
    """
    probs = probs.cpu().numpy().squeeze()

    fig, (ax1, ax2) = plt.subplots(figsize=(8,15), ncols=2)
    ax1.imshow(img.resize_(1, 28, 28).cpu().numpy().squeeze(), cmap='Greys_r')
    ax1.axis('off')
    ax1.set_title('Actual: {}'.format(classes[label]))
    ax2.barh(np.arange(10), probs)
    ax2.set_aspect(0.1)
    ax2.set_yticks(np.arange(10))
    ax2.set_yticklabels(classes, size='small');
    ax2.set_title('Predicted: probabilities')
    ax2.set_xlim(0, 1.1)

    plt.tight_layout()

# %%
# Calculate the class probabilites (log softmax) for img
images = iter(dl)
for imgs, labels in images:
    with torch.no_grad():
        model.eval()
        # Calculate the class probabilites (log softmax) for img
        probs = torch.nn.functional.softmax(model(imgs[0].unsqueeze(0)), dim=1)
        # Plot the image and probabilites
        view_prediction(imgs[0], labels[0], probs, dataset.classes)
    break

# %% [markdown]
# ## Save the model

# %%
# Very important
torch.save(model, 'model')

# %% [markdown]
# ## Question 4
#
# ## Compute accuracy on the test set

# %%
test_dataset = FashionMNIST('MNIST_data/', download = True, train = False, transform = transform)

# %%
test_dl = DataLoader(test_dataset, 100)
test_dl = DeviceDataLoader(test_dl, device)

# %%
def evaluate(model, test_dl):
    """
    Evaluates your model on the test data.
    
    Args:
        model: ImageClassifierNet object
        test_dl: test dataloader
    
    Returns: 
        Test accuracy.
    """
    ######################
    correct = 0
    total = 0
    #   YOUR CODE HERE   #
    for images, labels in test_dl:
        images, labels = images.to(device), labels.to(device)
        #labels_list.append(labels)
        #print(images.shape)

        test = Variable(images.view(100, 1, 28, 28))


        outputs = model(test)
        #val_loss = loss_fn(outputs, labels)
        predictions = torch.max(outputs, 1)[1].to(device)
        #predictions_list.append(predictions)
        correct += (predictions == labels).sum()
        total += 100

    #val_loss = val_loss.detach().cpu().numpy()
    #val_losses.append(val_loss)
    test_accuracy = correct * 100 / total
    test_accuracy = test_accuracy.detach().cpu().numpy()
    #val_accuracies.append(test_accuracy)
    return test_accuracy
    ######################

# %%
print("Test Accuracy = {:.4f}".format(evaluate(model, test_dl)))
# Out:
# Test Accuracy = 90.6900

# %%
# !pip install wget
# Out:
# Requirement already satisfied: wget in /usr/local/lib/python3.7/dist-packages (3.2)

# %% [markdown]
# ## Preparing the CSV for Kaggle submission

# %%
import zipfile
from tqdm import tqdm
from torchvision.io import read_image
# !wget --no-check-certificate \
    "https://people.tamu.edu/~sumedhpendurkar/csce633/test_private/dataset.zip" \
    -O "/tmp/dataset.zip"
zip_ref = zipfile.ZipFile('/tmp/dataset.zip', 'r') #Opens the zip file in read mode
zip_ref.extractall('./tmp') #Extracts the files into the /tmp folder
zip_ref.close()
# Out:
# --2022-05-05 04:30:10--  https://people.tamu.edu/~sumedhpendurkar/csce633/test_private/dataset.zip
# Resolving people.tamu.edu (people.tamu.edu)... 128.194.54.37
# Connecting to people.tamu.edu (people.tamu.edu)|128.194.54.37|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6101143 (5.8M) [application/zip]
# Saving to: ‘/tmp/dataset.zip’
#
# /tmp/dataset.zip    100%[===================>]   5.82M  17.1MB/s    in 0.3s
#
# 2022-05-05 04:30:10 (17.1 MB/s) - ‘/tmp/dataset.zip’ saved [6101143/6101143]

# %%
from torch.utils.data import Dataset
import pandas as pd
from tqdm import tqdm
from google.colab import files

class PrivateImageDataset(Dataset):
    def __init__(self, base_path, length, transform=None):
        self.base_path = base_path
        self.transform = transform
        self.length = length

    def __len__(self):
        return (self.length)

    def __getitem__(self, idx):
        path = self.base_path + str(idx) + '.png'
        im = Image.open(path)
        if self.transform:
            image = self.transform(im)
        return image, 0

# %%
def get_test_labels(model, dataset_size):
    test_dataset = PrivateImageDataset('./tmp/', dataset_size, transform=transform)
    test_dl = DataLoader(test_dataset, batch_size)
    test_dl = DeviceDataLoader(test_dl, device)
    preds, labels = [], []
    with torch.no_grad():
        model.eval()
        
        for i, data in tqdm(enumerate(test_dl)):
            xb, yb = data
            y_pred = model(xb)
            _, y = torch.max(y_pred, dim=1)
            preds.extend(y_pred)
            labels.extend(y)
    return preds, labels

# %%
def create_csv_for_kaggle(model):
    dataset_size = 10000
    _, labels = get_test_labels(model, dataset_size)
    data = []
    for i in range(len(labels)):
        data.append([str(i) + '.png', labels[i].item()])
    df = pd.DataFrame(data, columns=['id', 'label'])
    df.to_csv('submission.csv',index=False)
    files.download('submission.csv') 
    return df

# %%
create_csv_for_kaggle(model)
# Out:
# 334it [00:10, 31.46it/s]
#             id  label
# 0        0.png      9
# 1        1.png      2
# 2        2.png      1
# 3        3.png      1
# 4        4.png      6
# ...        ...    ...
# 9995  9995.png      9
# 9996  9996.png      1
# 9997  9997.png      8
# 9998  9998.png      1
# 9999  9999.png      7
#
# [10000 rows x 2 columns]
